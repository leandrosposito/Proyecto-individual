# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Verificar si la ruta existe
ruta_archivo = '/ruta/completa/al/movies_dataset.csv'

df_movie = pd.read_csv("./movies_dataset.csv")
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_276\250819881.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_movie = pd.read_csv("./movies_dataset.csv")

# %%
df_movie
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df_new = df_movie.copy()
df_new[["budget", "revenue"]].fillna(0, inplace = True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_276\78682604.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new[["budget", "revenue"]].fillna(0, inplace = True)

# %%
df_new
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df_new=df_new.dropna(subset=["release_date"])

# %%
df_new
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45460  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df_new.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40888
# budget                       0
# genres                       0
# homepage                 37610
# id                           0
# imdb_id                     14
# original_language           11
# original_title               0
# overview                   941
# popularity                   2
# poster_path                339
# production_companies         0
# production_countries         0
# release_date                 0
# revenue                      3
# runtime                    249
# spoken_languages             3
# status                      83
# tagline                  24981
# title                        3
# video                        3
# vote_average                 3
# vote_count                   3
# dtype: int64

# %%
df_new['release_date'] = pd.to_datetime(df_new['release_date'], format = "%Y-%m-%d" , errors='coerce')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_276\2623280388.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['release_date'] = pd.to_datetime(df_new['release_date'], format = "%Y-%m-%d" , errors='coerce')

# %%
df_new
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45460  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df_new["release_date"].dt.year
# Out:
# 0        1995.0
# 1        1995.0
# 2        1995.0
# 3        1995.0
# 4        1995.0
#           ...
# 45460    1991.0
# 45462    2011.0
# 45463    2003.0
# 45464    1917.0
# 45465    2017.0
# Name: release_date, Length: 45379, dtype: float64

# %%
df_new = df_new.dropna(subset="release_date")

df_new["release_year"] = df_new["release_date"].dt.year
df_new["release_year"] = df_new["release_year"].astype(int)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_276\2476841415.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["release_year"] = df_new["release_date"].dt.year
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_276\2476841415.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["release_year"] = df_new["release_year"].astype(int)

# %%
df_new
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45460  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df_new[["budget", "revenue"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45376 entries, 0 to 45465
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   budget   45376 non-null  object
#  1   revenue  45376 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.0+ MB

# %%
df_new["budget"] = df_new["budget"].astype(float)
df_new['return'] = df_new['revenue'] / df_new['budget'].replace(0, 1)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_276\1325563969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["budget"] = df_new["budget"].astype(float)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_276\1325563969.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['return'] = df_new['revenue'] / df_new['budget'].replace(0, 1)

# %%
df_new
# Out:
#        adult                              belongs_to_collection      budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1      False                                                NaN  65000000.0
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3      False                                                NaN  16000000.0
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
# ...      ...                                                ...         ...
# 45460  False                                                NaN         0.0
# 45462  False                                                NaN         0.0
# 45463  False                                                NaN         0.0
# 45464  False                                                NaN         0.0
# 45465  False                                                NaN         0.0
#
# ...

# %%
df_new.drop(columns = ["video","imdb_id", "original_title","poster_path" , "homepage"], inplace = True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_276\1473460848.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop(columns = ["video","imdb_id", "original_title","poster_path" , "homepage"], inplace = True)

# %%
df_new
# Out:
#        adult                              belongs_to_collection      budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1      False                                                NaN  65000000.0
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3      False                                                NaN  16000000.0
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
# ...      ...                                                ...         ...
# 45460  False                                                NaN         0.0
# 45462  False                                                NaN         0.0
# 45463  False                                                NaN         0.0
# 45464  False                                                NaN         0.0
# 45465  False                                                NaN         0.0
#
# ...
